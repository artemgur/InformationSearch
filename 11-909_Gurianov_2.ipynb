# %% [markdown]
# # Наивный байесовский классификатор

# %% [markdown]
# 1. Собрать датасет из любых двух открытых групп социальной сети VK (не менее 1500 непустых сообщений из каждой группы). Вывести (или сохранить во внешний файл) собранный датасет.
#
# 2. Разделить датасет на обучающую и тестовую выборки.
#
# 3. Попробовать различные методы предобработки текста (для лемматизации текстов на русском языке можyо попробовать библиотеку `pymorphy2` или  аналоги).
#
# 4. Используя наивный байесовский классификатор, научиться отличать тематику сообщений. Экспортировать словари в pkl файл.
#
# 5. Проверить результат классификации на тестовой выборке.
#
# 6. Написать отчет об этапах предподготовки данных и обучении модели. Описать последовательность работы над корпусом текстов для достижения лучшей точности классификации.

# %%
import numpy as np
import joblib

class Naive_bayes():

    def __init__(self):
        self.classes_cnt = {} # class_num: [dataset_class_counter, total_features_in_class_counter]
        self.freq = {}        # (feature, class_num): counter
        self.unique = set()   # unique features in dataset
        self.fitted = False

    def fit(self, dataset):
        for features, label in dataset:
            if label not in self.classes_cnt:
                self.classes_cnt[label] = [0, 0]
            self.classes_cnt[label][0] += 1
            for feature in features:
                if (feature, label) not in self.freq:
                    self.freq[(feature, label)] = 0
                self.freq[(feature, label)] += 1
                self.classes_cnt[label][1] += 1
                self.unique.add(feature)
        self.fitted = True

    def predict(self, features, alpha=1):
        if not self.fitted: return None
        dataset_cnt = 0
        for label in self.classes_cnt:
            dataset_cnt += self.classes_cnt[label][1]

        return max(self.classes_cnt.keys(),
                   key = lambda cl:
                   np.log10(self.classes_cnt[cl][0]/dataset_cnt) +
                   sum(np.log10((alpha + self.freq.get((feature, cl), 0))/\
                           (alpha*len(self.unique) + self.classes_cnt[cl][1]))
                       for feature in features))

    def export_model(self, path='dicts.pkl'):
        model = self.classes_cnt, self.freq, self.unique
        joblib.dump(model, path)
        return model

    def import_model(self, path='dicts.pkl'):
        self.classes_cnt, self.freq, self.unique = joblib.load(path)
        self.fitted = True

# %%
# %%capture
# !pip install nltk
# !pip install pymorphy2

# !pip install py-linq

# %%
posts_separator = '\n––––––––––\n'


def read_posts(filename):
    with open(filename, 'r', encoding='utf8') as file:
        return file.read().split(posts_separator)

# %%
posts0 = read_posts('itis_posts.txt')
print(len(posts0))
print(posts0[0])
# Out:
# 2005
# Директор ИТИС Михаил Абрамский выступит на очередной серии научно-популярного проекта PROНаука в КФУ 24 марта!💥

# %%
posts1 = read_posts('strategium_posts.txt')
len(posts1)
# Out:
# 2039

# %%
import random

random.seed(20)

random.shuffle(posts0)
random.shuffle(posts1)
print(posts0[0])
# Out:
# Наши дорогие ИТИСовцы, и будущие ИТИСовцы!
#
# Поздравляем ВАС с днем Всех Влюбленных!!!
# Будьте очень счастливы, самими собой во  всем. Веселых ВАМ вечеров с семьей, с друзьями, веселых поездок и походов в кино, в кафе, конечно же на пары!!!)) Крепких общих побед над всеми трудностями жизни! Желаем вам крепкую, большую, дружную семью, в которой даже в мелочах один за всех и все за одного!﻿
#
# В любви признавайтесь открыто.
#
# Не думайте, сколько Вам лет.
#
# Условности будут забыты.
#
# Границ для прекрасного нет.

# %%
from py_linq import Enumerable

# %%
def posts_to_words(posts):
    return (
        Enumerable(posts).select(lambda x: x.replace('\n', ' '))  # Replaces new lines with spaces
                         .select(lambda x: x.replace('_', ' '))  # Replaces underscores with spaces
                         .select(lambda x: x.split(' '))          # Split
                         .to_list()
    )

# %%
import nltk.corpus

nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words("russian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\artemgur\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from pymorphy2 import MorphAnalyzer

morph = MorphAnalyzer()

# %%
import re


def extract_word(s):
    # Regex which extracts true words.
    # Doesn't match one-letter words, but these are stopwords anyway
    match = re.match(r'[a-zа-яё]+-?[a-zа-яё]+', s)
    return match.group() if match else ''

# %%
def post_clear_noise(post: list[str]):
    return (
        Enumerable(post).select(lambda x: x.lower())                   # Lowercase
                        .where(lambda x: not ('http://' in x) and not ('https://' in x))  # Removes URLs
                        .select(extract_word)
                        .select(lambda x: morph.normal_forms(x)[0])    # Lemmatization
                        .where(lambda x: x)                            # Removes empty strings
                        .where(lambda x: x not in stopwords)           # Removes stopwords
                        .to_list()
    )

def posts_clear_noise(posts):
    return list(map(post_clear_noise, posts))

# %%
posts0_preprocessed = posts_clear_noise(posts_to_words(posts0))
posts0_preprocessed[0]
# Out:
# ['наш',
#  'дорогой',
#  'итисовца',
#  'будущий',
#  'итисовца',
#  'поздравлять',
#  'день',
#  'весь',
#  'влюбить',
#  'очень',
#  'счастливый',
#  'весь',
#  'весёлый',
#  'вечер',
#  'семья',
#  'друг',
#  'весёлый',
#  'поездка',
#  'поход',
#  'кино',
#  'кафе',
#  'пара',
#  'крепкий',
#  'общий',
#  'победа',
#  'весь',
#  'трудность',
#  'жизнь',
#  'желать',
#  'крепкий',
#  'больший',
#  'дружный',
#  'семья',
#  'который',
#  'мелочь',
#  'весь',
#  'всё',
#  'любовь',
#  'признаваться',
#  'открыто',
#  'думать',
#  'сколько',
#  'год',
#  'условность',
#  'забытый',
#  'граница',
#  'прекрасный']

# %%
posts1_preprocessed = posts_clear_noise(posts_to_words(posts1))

# %%
def posts_add_labels(posts, label):
    return list(map(lambda x: [x, label], posts))

# %%
train_size = 1500

posts0_train = posts0_preprocessed[:train_size]
posts0_test = posts0_preprocessed[train_size:]

posts1_train = posts1_preprocessed[:train_size]
posts1_test = posts1_preprocessed[train_size:]

# %%
bayes = Naive_bayes()
bayes.fit(posts_add_labels(posts0_train, 0) + posts_add_labels(posts1_train, 1))

# %%
len(bayes.freq)
# Out:
# 21583

# %%
def bayes_predict_many(bayes, posts):
    return list(map(bayes.predict, posts))

# %%
test_labels0 = [0] * len(posts0_test)
test_labels1 = [1] * len(posts1_test)
test_labels = test_labels0 + test_labels1

prediction0 = bayes_predict_many(bayes, posts0_test)
prediction1 = bayes_predict_many(bayes, posts1_test)
prediction = prediction0 + prediction1

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score

# %%
print('Accuracy:', accuracy_score(test_labels, prediction))
print('Accuracy on file 0:', accuracy_score(test_labels0, prediction0))
print('Accuracy on file 1:', accuracy_score(test_labels1, prediction1))
# Out:
# Accuracy: 0.9712643678160919
# Accuracy on file 0: 0.9900990099009901
# Accuracy on file 1: 0.9536178107606679

# %%
print('Precision:', precision_score(test_labels, prediction))
print('Recall:', recall_score(test_labels, prediction))
print('AUC ROC:', roc_auc_score(test_labels, prediction))
# Out:
# Precision: 0.9903660886319846
# Recall: 0.9536178107606679
# AUC ROC: 0.971858410330829

# %%
error_posts0 = Enumerable(posts0).zip(Enumerable(prediction0)).where(lambda x: x[1] == 1).select(lambda x: x[0])
for post in error_posts0:
    print(post)
    print(posts_separator)
# Out:
# #ИТИС_анонс #ИТИС_лагерь
# Ты школьник и мечтаешь научиться программировать роботов? Приглашаем тебя на Робо-лагерь в ИТИС КФУ с 29 октября по 3 ноября! Подробности в сюжете ниже!
# Стоимость смены: 10 000 руб (обед и экскурсии включены)
# ⏰Режим: понедельник (29.10)-суббота (3.11) с 9.00 до 18.00
# 📖Посмотреть программу: https://kpfu.ru/itis/v-osennie-kanikuly-itis-provedet..
# ✍🏻Записаться: https://itiskfu.timepad.ru/event/828188/
# ☎Контакты: juliya@it.kfu.ru
# 8 (843) 221-34-33 (доб.12)
#
# ––––––––––
#
# Высшая школа ИТИС и фирма 1С объявляет о проведении регионального отбора на конкурс "Умник". Победитель получит 200 000 рублей на реализацию проекта.
# Успей подготовить презентацию и подать заявку на участие до 29 октября. Подробнее здесь —->http://umnik.fasie.ru/1c/
#
# http://umnik.fasie.ru/1c/page/about-program.html
#
# ––––––––––
#
# #ИТИС_абитуриент2020 #ITISinternational
# В КФУ опубликованы приказы о зачислении иностранных студентов
# В приказе перечислены иностранные студенты бакалавриата и специалитета, которые будут обучаться на контрактной основе и в рамках квоты на обучение.
# Квоты на обучение устанавливаются Правительством РФ.
# https://admissions.kpfu.ru/priem-v-universitet/prikazy-o-zacislenii-2020
#
# ––––––––––
#
# Приглашаем на курс "Разработчик Java" ☕
# Данный курс дает возможность слушателям получить знания, необходимые при решении промышленных задач с использованием языка программирования Java. Слушатели смогут получить опыт разработки систем работы с базами данных через Java Технологии, изучат язык запросов SQL, получат опыт построения архитектуры баз данных. Основными и наиболее интересными блоками курса являются Java Web и Spring. Изучив данные технологии, слушатели смогут самостоятельно разрабатывать сложные клиентсерверные приложения и сайты с большой функциональностью.
#  ❗Начало курса 12 апреля 2022 года
# ❗Занятия проходят в КФУ: Кремлевская, 35 (ИТИС)
# Задать вопросы можно:
# Ирина Максимова, заместитель директора по развитию ИТИС КФУ
# 8 (843) 206-52-33 (доб. 3512)
# e-mail: i_maksimova@it.kfu.ru (в теме письма укажите название курса)
# 📝Для регистрации оставьте свои контактные данные ниже!
# https://itiskfu.timepad.ru/event/1968194/
# #ИТИС #КФУ #РазработчикJava
#
# ––––––––––
#
# Директор ИТИС Михаил Абрамский накануне выступил перед лицеистами КФУ с очень важной темой для начинающих ИТ-специалистов. Он рассказал как найти себя в профессии и состояться в цифровую эпоху.
#
# ––––––––––

# %%
len(error_posts0)
# Out:
# 5

# %%
error_posts1 = Enumerable(posts1).zip(Enumerable(prediction1)).where(lambda x: x[1] == 0).select(lambda x: x[0])
for post in error_posts1:
    print(post)
    print(posts_separator)
# Out:
# Разработчики Hitman(!!!) делают фэнтезийную RPG.
#
# Пока нет абсолютно никакой инфы, кроме той, что после релиза игру будут постоянно обновлять. Видимо, примерно как трилогию Hitman.
#
# Рабочее название игры - Project Fantasy.
#
# #rpg@strategium
#
# ––––––––––
#
# Продолжаем рассказывать подробности о #Dune: Spice Wars - помимо домов [https://vk.com/@strategium-dom-harkonnen-v-dune-spice-wars|Харконнен] и [https://vk.com/@strategium-dom-atreides-v-dune-spice-wars|Атрейдес] вы сможете выбрать фракцию Контрабандистов. Подробнее об особенностях фракции и её юнитах - в статье.
#
# Другие новости и информация по игре — по тегу #DuneSpiceWars@strategium
#
# ––––––––––
#
# Разработчики [https://vk.com/wall-31092576_11053|Knights of Honor II: Sovereign] — масштабной средневековой стратегии в режиме реального времени — посвятили новый дневник ИИ.
#
# При разработке одной их основных целей было обучить ИИ вести себя как живому игроку. Так, во время войны ИИ не будет просто собирать всё армию и атаковать. Он будет усиливать оборону, искать союзников, строить какие-то здания.
#
# У каждого бота будут приоритеты действий, зависимые от способностей короля. Дипломат будет больше вести переговоры и готовить рыцарей-послов, правитель с религиозными навыками заботиться о благочестии страны и набирать клериков. Разумеется, это не единственный фактор принятия решений, но важный.
#
# В текущей версии ИИ иногда ведёт себя хитро. Например, он приглашает вступить игрока в войну с королевством, с которым у бота тайный оборонительный союз. Или же он женит своего принца на принцессе игрока, а потом с помощью шпионов убивает ему короля и получает права на престол.
#
# Конечно, после нескольких сыгранных партий игрок поймёт, как работает ИИ, и сможет легче противодействовать ботам, но ведь и у живых игроков есть свой стиль игры, изучив который играть против человека становится проще.
#
# На высоких сложностях у ИИ будет генерироваться больше золота, рекрутов, благочестия и книг. В тактических сражениях сложность повлияет не только на характеристики. На лёгких сложностях войска игрока будут более стойкими к окружению. На высоких - ИИ будет больше фокусить лучников и бить с флангов своей кавалерией, а также лучше микроконтролить своих всадников-стрелков.
#
# Больше вестей с полей разработки можно найти по тегу #KoH2@strategium
# #news@strategium
#
# ––––––––––
#
# Компания Paradox Interactive сообщает о выходе специальной UWP-версии (Universal Windows Platform) градостроительного симулятора Cities: Skylines от студии Colossal Order для Xbox One и Windows 10.
#
# Cities: Skylines – Xbox One Edition предложит вам стать во главе растущего города, и вам предстоит не только развивать его и строить новые дороги, но и удовлетворять нужды растущего в числе населения. Планируйте, стройте и руководите городом вашей мечты, начиная с публичных сервисов заканчивая гражданскими политиками, поставив перед собой трудную цель превратить небольшой провинциальный городок в огромный метрополис.
#
# В издание Cities: Skylines для Xbox One уже входит первое дополнение After Dark, а сама игра получила оптимизированные интерфейс и управление для консольного геймпада.
#
# https://www.youtube.com/watch?v=K8i7JExxSiw
#
# ––––––––––
#
# 1 сентября, в 18:00 по МСК вышло дополнение The Grim & The Grave для стратегии Total War: WARHAMMER. И игрокам предстоит увидеть:
#
# • Два новых легендарных лорда с собственными цепочками заданий, магическими предметами и деревьями навыков.
# • Два новых типа лордов, пять совершенно новых видов войск с вариациями.
# • Пять новых полей сражений для своих и сетевых битв, 18 элитных знаменитых отрядов.
#
# Также компания Creative Assembly решила рассказать игрокам о своих планах на будущее. И удалось узнать, что:
#
# - Сейчас на разных стадиях производства находятся 3 платных DLC и бесплатные обновления.
# - Идет обсуждение планов по поводу бонуса за предзаказ, DLC и бесплатных обновлений для второй игры трилогии WARHAMMER.
# - Работа над второй игрой идет уже достаточно длительное время. И основная часть членов команды трудится над созданием огромного количества контента. Дизайн новых рас строится на основе отзывов, полученных от первой игры, и команда постарается сильнее подчеркнуть разницу в игровом процессе между расами, и придать им еще больше уникальности.
#
# “Намереваясь погрузить Империю в вечную тьму, коварная и безжалостная полуночная аристократия призвала новых кошмарных тварей. Ужасные стриги - древние короли упырей - вылезают на запах крови из своих катакомб, а Гельман Горст, самый зловещий из учеников Манфреда, отложил свои штудии, чтобы готовить к битве новые труповозки.
#
# Но гордые люди Империи не сдаются. В этот тяжелый час все взгляды прикованы к Фолькмару Мрачному - Великому теогонисту зигмаритов. Благочестивый, суровый и всецело преданный Карлу Францу, Фолькмар призывает своих архилекторов и мчится в бой на воинском алтаре Зигмара, наполняя ужасом небьющиеся сердца нежити.”
#
# https://www.youtube.com/watch?v=06-bjClnpdk
#
# ––––––––––
#
# Предлагаем начать долгожданные выходные с первого обзора на Manor lords от нашего соавтора [https://vk.com/romanca_opps|Романа Гуреева].
#
# Manor lords градостроительная стратегия, дарующая возможность окунуться в жизнь средневекового властителя. Максимальное погружение обеспечивает красивая графика и приятная фоновая музыка.
#
# Игра от польского разработчика (Hooded Horse), дарует в правление маленькую деревню,вам предстоит превратить её в мощный военно- экономический и центр. Релиз обещан в 2023 году.
# Заявленные особенности:
#
# - Полный контроль за выстраиванием логистики и распределениям ресурсов в торговых отношениях.
# - Рельеф предопределяет планировку, строительство и будущие логистические неурядицы.
# - Реалистичные сражения, подготовка и снаряжение воинов.
# -За основу взята франконскую живопись и архитектура конца XIV века.
# -Обозначайте зоны жилых районов, люди сами застроят выделенную землю в соответствии с исторической системой аренды феодальной земли.
# -Домовладельцы не просто платят налоги — они выращивают овощи, разводят кур и коз. Обеспечивают себя и соседей всем необходимым в дополнение к тому, что производят ваши фермы, пастбища и мануфактуры.
# -Дипломатия позволит вам воздействовать на других лордов, используя свое влияние и силу. Однако не забывайте, что они тоже преследуют свои цели!
# -Русский язык уже представлен в игре.
#
# #Manorlords@strategium
# #review@strategium
#
# ––––––––––
#
# Отличные новости для суровых градостроителей Workers&Resourses: #SovietRepublic: работа над [https://vk.com/wall-31092576_10364|режимом космонавта] почти завершена, так что разработчики снова сосредоточились на транспорте.
#
# Помимо уже обещанных изменений трамвайной сети, о которых мы [https://vk.com/wall-31092576_11023|писали ранее], в игру будут добавлены новые трамвайные остановки: одна побольше, другая поменьше.
#
# Поскольку старые трамвайные пути сохранят свой функционал, разработчики предусмотрели соединение старого пути с новым - и показали, как это будет выглядеть (третья иллюстрация к посту).
#
# И ещё один прекрасный факт для любителей трамвая: теперь пантографы будут правильно подключаться как к проводам на обычных электрифицированных железных дорогах, так и на новых трамвайных путях.
#
# Помимо трамвайных изменений, в игре появятся два новых двенадцатиэтажных жилых здания, а так же будет добавлена новая настройка для теней. При выставлении "ультра" уровня теней все здания будут отбрасывать тени в том числе и на движущиеся транспортные средства.
#
# Подробнее про грядущие изменения в транспортной системе, про новый игровой режим и про многое другое - по тегу #SovietRepublic@strategium
#
# #news@strategium
#
# ––––––––––
#
# В Total War: Warhammer 3 переделают войска!
#
# Перейдём сразу к делу:
# -В DLC на кровь будет ползунок интенсивности кровопусканий (Кхорн одобряет максимальный уровень!)
# -Архаон (и многие легендарные лорды) получит ребаланс умений и предметов + будет получать бонусы от вассализации фракций хаоса.
# -Возможно мы сможем сбрасывать навыки лордам фракции, взятых в конфедерацию.
# -Воины Хаоса получат добавляемых в обновлениях юнитов демонов, демоны — новых юнитов Воинов Хаоса, а Даниэль получает всех демонов, но не смертных.
# -Рыцари Тзинча и других богов получат новые модели скакунов.
# -ИИ вассалов станет более надежным и заставит другие фракции учитывать волю хозяина.
#
# Больше новостей из обречённого мира по тегу #БессмертныеИмперии@strategium и #TotalWarWARHAMMERIII@strategium
#
# #ImmortalEmpires #БессмертныеИмперии
# #TotalWar #WARHAMMERIII #TotalWarWARHAMMERIII
# #news@strategium
#
# ––––––––––
#
# Продолжаем делиться новостями о следующем обновлении для HUMANKIND - помимо [https://vk.com/wall-31092576_11992|новых имён противников] оно визуально обновит города, улучшит всплывающие подсказки и изменит систему видимости в бою.
#
# С обновлением Ibn Battuta ваши города станут менее однообразными благодаря автоповороту кварталов при постройке. А для максимально красивых скриншотов городов настроена горячая клавиша “Переключить пользовательский интерфейс”, убирающая границы территории.
#
# Всплывающие подсказки при выборе социального института, добавленные в [https://vk.com/wall-31092576_10496|обновлении Боливар], будут улучшены - теперь в подсказках будут эффекты обоих вариантов каждого социального института для более быстрого выбора.
#
# Наконец, будет пересмотрена система прямой видимости - теперь леса в низине не будут мешать вашей пушке на холме - в конце концов, в лесу же не многовековые секвойи растут. Теперь ваша линия фронта должна немного меньше мешать стрельбе и рельеф будет оказывать большее влияние.
#
# Обновление запланировано на конец июля.
# Предыдущие новости человечества по тегу #HUMANKIND@strategium
#
# #news@strategium
#
# ––––––––––
#
# Новости из мира Total War: WARHAMMER III - в этом году планируется выпустить обновление 2.3, а во втором квартале 2023 года ожидается патч 3.0.
#
# Разработчики рассказали о планах на будущее: в дальнейшем в игре появится больше кризисов. В частности, ожидаются следующие кризисы: имперский во главе с Карлом Францом и людоящерский, чтобы хорошие парни стали злодеями.
#
# Патч 2.3 в основном будет нацелен на исправление текущих проблем и какие-то небольшие улучшения. Помимо обновления 3.0, во втором квартале 2023 игроков ждёт четвёртый набор знаменитых юнитов.
#
# Все записи об игре: #TotalWarWARHAMMERIII@strategium
#
# #TotalWar #WARHAMMERIII
# #news@strategium
#
# ––––––––––
#
# В ранний доступ вышла The Wandering Village, предлагающая построить поселение на спине огромного животного (нет, не на черепахе).
#
# Создание, на котором живут ваши люди, именуется Онбу. Станете ли вы выстраивать с Онбу доверительные отношения или будете просто эксплуатировать его? Игра предоставляет выбор.
#
# По ходу путешествия придется постоянно приспосабливаться к изменяющимся условиям разных биомов, через которые идёт Онбу: в каждом свой климат, возможности и опасности. Окружающий мир недружелюбен, но в нём можно найти ценные ресурсы и дневник артефакты.
#
# Ядовитые споры, кровососущие паразиты, суровый климат — весь мир будет против вас, и только Онбу готов подставить людям свою огромную спину.
#
# Ранний доступ продлится больше года и принесёт в игру больше механик, зданий и событий. Перевод на русский язык присутствует: https://vk.cc/cgzXvy
#
# #TheWanderingVillage
# #release@strategium
# #earlyaccess@strategium
#
# ––––––––––
#
# #news@strategium
#
# Один из основателей Playdead считает - 4K-разрешение «бесполезное»
#
# Дино Патти, являющийся сооснователем студии Playdead, на конференции Reboot Develop в Канаде подчеркнул, что 4K-разрешение «бесполезное».
# _________________________________________________
# Его (4к разрешение) лоббируют поставщики железа, чтобы реализовать следующие консоли. Я хочу выбрать путь самостоятельно, а не быть привлечённым деньгами.
#
# Множество людей видит что-то блестящее и идут за этим. Вы определённо наблюдаете за стадом, идущим в определенную сторону и желающим попасть в пропасть.
#
# Технологию Кинект от Майкрософт продвигали путем денежных поощрений разработчикам игр, но для пользователей радости не принесло.
#  Дино Патти
# __________________________________________________________________
#
# Представитель от студии Klang Games Гудмундр Халльгримссон на конференции выступил с заявлением, что в игре Seed отказались от мощной графики, выбрав упрощённый графический стиль, а также он считает, главное в играх это игровой процесс.
#
# ––––––––––
#
# #news@strategium
#
# Kerbal Space Program вышла в ранний доступ в 2010 году, а в 2015 студия объявила об официальном релизе. В последствии выпустили два крупных платных дополнения: Making History и Breaking Ground.
#
# Kerbal Space Program прошла долгий путь, и её развитие окончено.
#
# Команда разработчиков продолжит творить, но уже работая над Kerbal Space Program 2! Релиз должен состояться в 2022 году.
#
# ––––––––––
#
# Для Northgard вышло DLC Hræsvelg, Clan of the Eagle.
#
# Клан Орла добавляет в геймплей птичников и ястребов, которых можно отправить исследовать новые территории и собирать ресурсы на могильниках.
#
# Бонусы клана:
#
# — Птичник заменяет лагерь разведчиков и не требует места для строительства. Сокольников нельзя ранить и они не могут собирать предания, пока исследуют новые территории.
# — Зачищенные зоны превращаются в могильники. В течение 2 месяцев существа в этих зонах исцеляются, а ястребы будут собирать ресурсы. Число ястребов на могильниках зависит от того, сколько врагов здесь было убито и сколько птичников вы построили.
# — Ваши птичники со временем откроют на карте закопанный тайник.
#
# #northgard@strategium
# #dlc@strategium
#
# ––––––––––
#
# Strategium не только освещает стратегические новости, но и дарит ключи!
# Новый розыгрыш совместно с магазином ключей [club93893399|GabeStore] - воспользуйтесь шансом получить [https://vk.com/wall-31092576_17990|Knights of Honor II: Sovereign].
#
# Полные условия участия:
# - лайк этой публикации;
# - участие в группах [club31092576|Strategium] и [club96633960|Crusader Kings III Strategium];
# - открытая нефейковая страница.
#
# Счастливчик будет объявлен 25 декабря и [https://vk.com/knights_of_honor|коммьюнити по серии игр Knights of Honor] будет радо видеть его в своих рядах.
#
# ––––––––––
#
# В Steam вышла историческая инди-стратегия Warlord: Britannia, предлагающая возглавить римский экспедиционный корпус и завоевать Британию.
#
# Разработчики предлагают попробовать игру от первого лица, в которой вы сможете сражаться бок о бок со своими легионерами в реальном времени. И не только сражаться - продвигаясь по острову, вам придётся строить походные лагеря, возводить стены, заботиться об выставлении охраны и патрулей.
#
# Все игровое оружие, доспехи, сооружения и названия вдохновлены сохранившимися историческими материалами и археологическими находками.
#
# Отзывы очень положительные (89% из 201). Игра представлена только на английском языке: https://vk.cc/cdZN4T
#
# #news@strategium
#
# ––––––––––
#
# #review@strategium
# #mobile@strategium
# Знаете ли вы стратегии, портированные или даже специально разработанные для игры на мобильных устройствах? Если да, предлагаем обменяться рекомендациями: в сегодняшнем посте речь пойдёт об игре от разработчика знаменитой Plague Inc – Rebel Inc: Escalation. Этой осенью #RebelInc вышла из раннего доступа и доступна как на ПК, так и на телефонах или планшетах. В статье приведён краткий обзор и сравнение стимовской версии с мобильной. Кстати, до 15 ноября в стиме действует скидка 25%!
#
# ––––––––––
#
# Набираем команду.
# Планируется создать новую версию игры "Soldiers of Empires", подразумевая не просто существенно модернизировать сами возможности игры, но и сделать сценарий на основе альтернативной реальности "Мир Великих Империй".
# В связи с этим нужны люди для следующих направлений:
# - создание сценария игры;
# - участие в доработке альтернативной реальности "Мир Великих Империй" во всем, что необходимо для разработки сценария;
# Требования:
# - хорошее знание военной истории, в первую очередь периода Второй Мировой войны и готовность учиться в этом направлении;
# - готовность работать в команде на общий результат, понимание сложностей проектов (в частности то, что работа идёт даже не месяцами);
# - желательно умение работать с графикой;
# - если есть опыт работы над созданием игр - это замечательно.
#
# Важный момент - проект коммерческий, со всеми вытекающими последствиями.
#
# Для информации:
# Игра "Soldiers of Empires" - классическая пошаговая стратегия по Второй Мировой войне, в первую очередь интересная своей масштабностью - в ней моделируются все вооруженные силы, всех стран планеты, и существует возможность моделировать боевые действия в масштабах планеты.
# Альтернативная реальность "Мир Великих Империй" - специально разработанный альтернативный мир, с изменением географии планеты, в котором сделана глубокая проработка вооруженных сил всех стран, на основе реальных тенденций первой половины ХХ века, с целью смоделировать самые различные варианты развития военного дела и военной техники.
#
# Дополнительно.
# В рамках развития игры "Soldiers of Empires" планируется сделать сценарии Первая Мировая война и Третья Мировая война, поэтому для любителей создавать сценарии и интересующихся данными периодами, так же есть о чём поговорить.
# Формируется команда для создания коммерческого сайта "Военно-исторический клуб", куда приглашаются все, кому интересны любые направления военной истории, военной техники и оружия, и любых близких тематик, и кто готов работать в этом направлении.
#
# Обращаться в личку или на почту nwt@nweb.su.
#
# ––––––––––
#
# Войны звездного масштаба в режиме реального времени с возможностью аннигилировать целые планеты - звучит как план на новогодние каникулы, не так ли?
#
# Сегодня мы предлагаем вспомнить (или впервые узнать) RTS Planetary Annihilation Titans.
#
# #pa #rts #review@strategium
#
# ––––––––––
#
# Официальные итоги выборов.
#
# Партия Геймеров и Мододелов [ 36 ] [20.34%]
# SPQS - Сенат и Народ Стратегиума [ 30 ] [16.95%]
# Партия Стратегиум Вконтакте [ 8 ] [4.52%]
# Блок Социал-Демократический Союз [ 54 ] [30.51%]
# Партия Белое Дело [ 49 ] [27.68%]
#
# Министры:
# ПГиМ 20,34*7/100=1,42 > 1+1= 2 министра
# SPQS 16,95*7/100=1,19 > 1+0 = 1 министр
# ПСВК 4,52*7/100=0,32 > 0 = 0 министров
# БСДС 30,51*7/100=2,14 > 2+0 = 2 министра
# Белое Дело 27,68*7/100=1,94 > 1+1 = 2 министра
#
# Парламентарии:
# ПГиМ 20,34*13/100=2,64 > 2+1= 3 парламентария
# SPQS 16,95*13/100=2,20 > 2+0 = 2 парламентария
# ПСВК 4,52*13/100=0,59 > 0 = 0 парламентариев
# БСДС 30,51*13/100=3,97 > 3+1 = 4 парламентария
# Белое Дело 27,68*13/100=3,60 > 3+1 = 4 парламентария
#
# http://www.strategium.ru/forum/index.php?s=&showtopic=79350&view=findpost&p=2084913
#
# ––––––––––
#
# Продолжаем погружение в мир #Warhammer Fantasy!
#
# Сегодня [id13659175|Ярослав], [id10152319|Кирилл] и [id157756789|Роза] подготовили рассказ об эльфах: откуда пошёл титул Короля-Феникса и как он наследовался, как в мир эльфов проникли культы Хаоса и начался Раскол.
#
# Предыдущий пост с началом истории — по тегу #fonoteka@strategium
#
# ––––––––––
#
# Опубликован второй дневник по [https://vk.com/wall-31092576_11344|SpellForce: Conquest of Eo], в котором разработчики показали часть карты и углубились в лор.
#
# Действие пошаговой стратегии будет происходить до событий Созыва, поэтому перед разработчиками стоит задача одновременно дать игрокам свободу действий и не поменять при этом будущее вселенной. Поэтому в игре не будет глобальных событий, меняющих историю завоеванных наций и свергнутых королевств.
#
# Как видно из показанного куска карты, начало игры будет в области, где царят люди, но совсем рядом расположены вотчины орков и гномов.
#
# У каждого героя, который присоединится к вам, будет своя предыстория, которую вы будете узнавать в процессе совместных приключений. В случае с гномами вы точно познаете много нового про бомбы и другие способы устроить впечатляющий взрыв.
#
# Предыдущий дневник можно найти по тегу #SpellForce@strategium
# #news@strategium
#
# ––––––––––
#
# Представьте себе средневековое королевство, вдохновлённое мирами Rimworld, Crusader Kings и Caesar. Именно там будет разворачиваться действие Norland – российской стратегии, о которой пойдёт речь в рамках еженедельной рубрики интересных проектов в разработке.
#
# В игре нам предстоит управлять средневековым городом от лица благородной семьи со сложными взаимоотношениями. Тяжела жизнь аристократа: заботиться придётся как об отсутствии толпы с вилами под вашими окнами, так и об отсутствии яда в вашем бокале, поданном заботливым родственником.
#
# Действие происходит в 10 веке с его суровыми нравами. Если всю вашу семью убьют, вы проиграете – поэтому на Norland можно посмотреть и как на игру-выживание в агрессивной социальной среде. Кстати об агрессивной среде: соседние государства тоже будут представлять угрозу, но вы можете выстроить с ними союзные отношения.
#
# Разработчики планируют выпустить игру сразу в релиз, минуя ранний доступ, взамен которого предлагают всем участникам своего дискорд сервера принять участие в альфа и бета тестировании, которое планируют начать уже весной. Сам релиз намечен на осень 2022 года.
#
# Группа разработчика: https://vk.com/norlandgame
# https://store.steampowered.com/app/1857090/Norland/
#
# #monday@strategium
# #rusgame@strategium
#
# ––––––––––
#
# В ранний доступ вышла Astro Colony, предлагающая колонизировать и автоматизировать бескрайнюю вселенную.
#
# Разработчик предлагает погрузиться в процедурно генерируемую полностью разрушаемую вселенную и обустроить её по вашему вкусу.
#
# Исследуйте, автоматизируйте, стройте конвейеры и трубопроводы, приглашайте колонистов, обеспечивайте им все условия. И не забывайте об опасностях — космос коварен!
#
# Ранний доступ продлится около года и принесёт полную поддержку пользовательских модификаций, геймпада и возможность многопользовательской игры с выделенным серверами.
#
# Первые отзывы покупателей положительные. Игра переведена на русский язык, до 14 ноября действует скидка: https://vk.cc/cipLoY
#
# #release@strategium #earlyaccess@strategium
# #AstroColony
#
# ––––––––––
#
# Пятнадцатое обновление и DLC Empire of the Skies для Anno 1800 уже доступны!
#
# Как обычно, вместе с новым контентом пришло и новое испытание — точнее, два испытания. Первое ставит перед сообществом цель построить 500 000 дирижаблей, а второе — возвести 250 000 огневых точек и башен.
#
# В качестве награды за основное испытание игроков ждёт новое изображение для рекламного щита.
#
# Кстати, до 29 сентября за просмотр трансляций на твиче можно получить уникальный декор — подробнее в [https://vk.com/wall-31092576_14822|предыдущей публикации].
#
# Все посты о дирижаблях и не только — по тегу #Anno1800@strategium
#
# #dlc@strategium
#
# ––––––––––

# %%
len(error_posts1)
# Out:
# 25

# %%
bayes.export_model()
# Out:
# ({0: [1500, 56030], 1: [1500, 101858]},
#  {('наш', 0): 346,
#   ('дорогой', 0): 63,
#   ('итисовца', 0): 13,
#   ('будущий', 0): 13,
#   ('поздравлять', 0): 118,
#   ('день', 0): 322,
#   ('весь', 0): 305,
#   ('влюбить', 0): 1,
#   ('очень', 0): 43,
#   ('счастливый', 0): 13,
#   ('весёлый', 0): 6,
#   ('вечер', 0): 9,
#   ('семья', 0): 10,
#   ('друг', 0): 62,
#   ('поездка', 0): 5,
#   ('поход', 0): 1,
#   ('кино', 0): 4,
#   ('кафе', 0): 3,
#   ('пара', 0): 16,
#   ('крепкий', 0): 6,
#   ('общий', 0): 36,
#   ('победа', 0): 54,
#   ('трудность', 0): 3,
#   ('жизнь', 0): 58,
#   ('желать', 0): 82,
#   ('больший', 0): 26,
#   ('дружный', 0): 7,
#   ('который', 0): 299,
#   ('мелочь', 0): 1,
#   ('всё', 0): 192,
#   ('любовь', 0): 2,
#   ('признаваться', 0): 1,
#   ('открыто', 0): 1,
#   ('думать', 0): 11,
#   ('сколько', 0): 5,
#   ('год', 0): 393,
#   ('условность', 0): 1,
#   ('забытый', 0): 4,
#   ('граница', 0): 4,
#   ('прекрасный', 0): 12,
#   ('ирина', 0): 20,
#   ('максимов', 0): 16,
#   ('заместитель', 0): 31,
#   ('директор', 0): 146,
#   ('высокий', 0): 581,
#   ('школа', 0): 567,
#   ('итис', 0): 1170,
#   ('развитие', 0): 84,
#   ('наградить', 0): 7,
#   ('благодарственный', 0): 3,
#   ('письмо', 0): 18,
#   ('министр', 0): 17,
#   ('информатизация', 0): 14,
#   ('связь', 0): 60,
#   ('роман', 0): 18,
#   ('шайхутдинов', 0): 3,
#   ('подробность', 0): 90,
#   ('page', 0): 107,
#   ('cid', 0): 107,
#   ('view', 0): 102,
#   ('random', 0): 99,
#   ('интервью', 0): 22,
#   ('олег', 0): 7,
#   ('курносов', 0): 1,
#   ('сооснователь', 0): 4,
#   ('компания', 0): 125,
#   ('flatstack', 0): 3,
#   ('партнёр', 0): 47,
#   ('внутри', 0): 13,
#   ('приятный', 0): 15,
#   ('слово', 0): 29,
#   ('читать', 0): 64,
#   ('важно', 0): 11,
#   ('знать', 0): 58,
#   ('ваш', 0): 82,
#   ('мнение', 0): 10,
#   ('идея', 0): 71,
#   ('ребята', 0): 71,
#   ('детский', 0): 17,
#   ('лагерь', 0): 29,
#   ('программирование', 0): 116,
#   ('вчера', 0): 13,
#   ('it-парка', 0): 2,
#   ('накануне', 0): 19,
#   ('представить', 0): 77,
#   ('деятельность', 0): 60,
#   ('свой', 0): 308,
#   ('научный', 0): 94,
#   ('кружок', 0): 4,
#   ('руководство', 0): 17,
#   ('университет', 0): 175,
#   ('фестиваль', 0): 33,
#   ('мир', 0): 84,
#   ('наука', 0): 69,
#   ('михаил', 0): 61,
#   ('абрамский', 0): 58,
#   ('презентовать', 0): 8,
#   ('стенд', 0): 1,
#   ('институт', 0): 115,
#   ('интеллектуальный', 0): 92,
#   ('робототехника', 0): 130,
#   ('технология', 0): 209,
#   ('виртуальный', 0): 61,
#   ('дополнить', 0): 33,
#   ('реальность', 0): 45,
#   ('smart', 0): 6,
#   ('education', 0): 10,
#   ('lab', 0): 41,
#   ('база', 0): 54,
#   ('большой', 0): 82,
#   ('количество', 0): 40,
#   ('студент', 0): 563,
#   ('выполнять', 0): 4,
#   ('работа', 0): 152,
#   ('сторона', 0): 15,
#   ('преподаватель', 0): 115,
#   ('ментор', 0): 4,
#   ('куратор', 0): 14,
#   ('непосредственный', 0): 3,
#   ('руководитель', 0): 92,
#   ('расставляться', 0): 1,
#   ('акцент', 0): 2,
#   ('повышать', 0): 2,
#   ('шанс', 0): 23,
#   ('пропустить', 0): 18,
#   ('потенциал', 0): 6,
#   ('иметься', 0): 3,
#   ('отметить', 0): 14,
#   ('майя', 0): 2,
#   ('рудаков', 0): 2,
#   ('участвовать', 0): 42,
#   ('также', 0): 188,
#   ('научно-познавательный', 0): 1,
#   ('квест', 0): 4,
#   ('квизе', 0): 1,
#   ('бой', 0): 7,
#   ('зачёт', 0): 12,
#   ('кфу', 0): 427,
#   ('малый', 0): 9,
#   ('группа', 0): 106,
#   ('занять', 0): 27,
#   ('место', 0): 232,
#   ('студентка', 0): 21,
#   ('курс', 0): 316,
#   ('мария', 0): 2,
#   ('иванов', 0): 7,
#   ('личный', 0): 35,
#   ('конкурс', 0): 123,
#   ('русский', 0): 21,
#   ('язык', 0): 109,
#   ('рамка', 0): 79,
#   ('это', 0): 347,
#   ('участник', 0): 127,
#   ('конкурсный', 0): 5,
#   ('испытание', 0): 25,
#   ('открыть', 0): 28,
#   ('информационный', 0): 81,
#   ('уважаемый', 0): 53,
#   ('родитель', 0): 35,
#   ('самостоятельный', 0): 7,
#   ('ребёнок', 0): 13,
#   ('октябрь', 0): 57,
#   ('сезон', 0): 5,
#   ('ждать', 0): 196,
#   ('школьник', 0): 122,
#   ('занятие', 0): 61,
#   ('перезагрузка', 0): 2,
#   ('никакой', 0): 13,
#   ('лекция', 0): 122,
#   ('практика', 0): 40,
#   ('полезный', 0): 31,
#   ('знание', 0): 53,
#   ('итак', 0): 15,
#   ('продолжать', 0): 32,
#   ('второй', 0): 51,
#   ('выпуск', 0): 21,
#   ('екатерина', 0): 4,
#   ('бобринский', 0): 2,
#   ('лаборатория', 0): 159,
#   ('технологический', 0): 22,
#   ('предпринимательство', 0): 13,
#   ('рассказать', 0): 146,
#   ('заработать', 0): 11,
#   ('деньга', 0): 11,
#   ('выходить', 0): 8,
#   ('браслет', 0): 2,
#   ('работать', 0): 67,
#   ('абитуриент', 0): 426,
#   ('агентство', 0): 9,
#   ('times', 0): 3,
#   ('higher', 0): 3,
#   ('опубликовать', 0): 17,
#   ('новый', 0): 251,
#   ('предметный', 0): 5,
#   ('рейтинг', 0): 21,
#   ('учебный', 0): 79,
#   ('заведение', 0): 4,
#   ('впервые', 0): 21,
#   ('войти', 0): 26,
#   ('science', 0): 26,
#   ('позиция', 0): 4,
#   ('внести', 0): 10,
#   ('часть', 0): 34,
#   ('достижение', 0): 23,
#   ('продемонстрировать', 0): 7,
#   ('наукометрический', 0): 1,
#   ('показатель', 0): 4,
#   ('стать', 0): 132,
#   ('средний', 0): 7,
#   ('взвесить', 0): 1,
#   ('цитирование', 0): 1,
#   ('процент', 0): 2,
#   ('международный', 0): 93,
#   ('коллаборация', 0): 2,
#   ('публикация', 0): 17,
#   ('дать', 0): 50,
#   ('область', 0): 86,
#   ('являться', 0): 42,
#   ('существенный', 0): 1,
#   ('оценка', 0): 21,
#   ('время', 0): 110,
#   ('продвижение', 0): 8,
#   ('неоценимый', 0): 2,
#   ('вклад', 0): 12,
#   ('показать', 0): 34,
#   ('неплохой', 0): 1,
#   ('публикационный', 0): 1,
#   ('активность', 0): 10,
#   ('ряд', 0): 14,
#   ('частность', 0): 5,
#   ('заниматься', 0): 24,
#   ('междисциплинарный', 0): 2,
#   ('исследование', 0): 26,
#   ('май', 0): 58,
#   ('публичный', 0): 7,
#   ('футуролог', 0): 2,
#   ('данил', 0): 10,
#   ('медведев', 0): 3,
#   ('открытый', 0): 154,
#   ('дверь', 0): 115,
#   ('человек', 0): 116,
#   ('богатый', 0): 5,
#   ('талантливый', 0): 10,
#   ('находить', 0): 7,
#   ('ит-сфера', 0): 8,
#   ('среди', 0): 47,
#   ('крутой', 0): 49,
#   ('спортсмен', 0): 6,
#   ('сей', 0): 1,
#   ('пора', 0): 5,
#   ('эйфория', 0): 1,
#   ('спортивный', 0): 14,
#   ('известный', 0): 14,
#   ('блогер', 0): 3,
#   ('музыкант', 0): 1,
#   ('танцор', 0): 1,
#   ('фотограф', 0): 4,
#   ('сегодня', 0): 110,
#   ('ксения', 0): 6,
#   ('чернышёв', 0): 1,
#   ('номинация', 0): 36,
#   ('семнадцатый', 0): 1,
#   ('молодёжный', 0): 14,
#   ('дельфийский', 0): 1,
#   ('игра', 0): 92,
#   ('россия', 0): 122,
#   ('гордиться', 0): 14,
#   ('магистрант', 0): 36,
#   ('начало', 0): 65,
#   ('приёмный', 0): 36,
#   ('кампания', 0): 25,
#   ('свет', 0): 2,
#   ('июнь', 0): 87,
#   ('июль', 0): 68,
#   ('найти', 0): 29,
#   ('казань', 0): 121,
#   ('ул', 0): 56,
#   ('корпус', 0): 42,
#   ('ссылка', 0): 159,
#   ('график', 0): 17,
#   ('проведение', 0): 28,
#   ('условие', 0): 29,
#   ('поступление', 0): 79,
#   ('секретарь', 0): 3,
#   ('каждый', 0): 84,
#   ('кроме', 0): 16,
#   ('воскресение', 0): 8,
#   ('мраморный', 0): 1,
#   ('зал', 0): 10,
#   ('табличный', 0): 1,
#   ('система', 0): 195,
#   ('столица', 0): 2,
#   ('it', 0): 55,
#   ('волга', 0): 2,
#   ('инновационный', 0): 31,
#   ('центр', 0): 38,
#   ('написать', 0): 30,
#   ('французский', 0): 5,
#   ('журнал', 0): 18,
#   ('review', 0): 1,
#   ('журналист', 0): 6,
#   ('посетить', 0): 19,
#   ('конец', 0): 27,
#   ('впечатлить', 0): 2,
#   ('cisco', 0): 7,
#   ('открыться', 0): 7,
#   ('urban', 0): 2,
#   ('moscow', 0): 2,
#   ('хакатон', 0): 100,
#   ('акселератор', 0): 5,
#   ('премиальный', 0): 1,
#   ('фонд', 0): 49,
#   ('рубль', 0): 83,
#   ('подробный', 0): 64,
#   ('смочь', 0): 87,
#   ('разработать', 0): 27,
#   ('цифровой', 0): 88,
#   ('продукт', 0): 38,
#   ('заключить', 0): 5,
#   ('контракт', 0): 18,
#   ('ведущий', 0): 39,
#   ('it-компания', 0): 14,
#   ('проект', 0): 282,
#   ('город', 0): 47,
#   ('направление', 0): 107,
#   ('city', 0): 5,
#   ('systems', 0): 3,
#   ('intelligence', 0): 4,
#   ('разработчик', 0): 59,
#   ('дизайнер', 0): 14,
#   ('project-менеджер', 0): 1,
#   ('ноябрь', 0): 49,
#   ('декабрь', 0): 34,
#   ('финальный', 0): 5,
#   ('команда', 0): 163,
#   ('отраслевой', 0): 2,
#   ('идеатон', 0): 1,
#   ('подать', 0): 40,
#   ('заявка', 0): 65,
#   ('участие', 0): 193,
#   ('сайт', 0): 131,
#   ('инновация', 0): 26,
#   ('москва', 0): 23,
#   ('машинный', 0): 27,
#   ('понимание', 0): 18,
#   ('максим', 0): 41,
#   ('талан', 0): 31,
#   ('победить', 0): 5,
#   ('премия', 0): 14,
#   ('самый', 0): 93,
#   ('знаменитый', 0): 7,
#   ('версия', 0): 14,
#   ('внедрение', 0): 19,
#   ('эмоция', 0): 26,
#   ('искусственный', 0): 38,
#   ('интеллект', 0): 43,
#   ('спасибо', 0): 43,
#   ('поддержать', 0): 23,
#   ('голос', 0): 9,
#   ('выйти', 0): 21,
#   ('phil', 0): 2,
#   ('марафон', 0): 16,
#   ('пройти', 0): 219,
#   ('генерация', 0): 4,
#   ('сфера', 0): 94,
#   ('ночёвка', 0): 1,
#   ('делать', 0): 24,
#   ('придумывать', 0): 4,
#   ('масштабировать', 0): 2,
#   ('решение', 0): 68,
#   ('организация', 0): 22,
#   ('социальный', 0): 29,
#   ('час', 0): 37,
#   ('узнать', 0): 82,
#   ('тренд', 0): 7,
#   ('рынок', 0): 19,
#   ('понять', 0): 10,
#   ('нужно', 0): 60,
#   ('будущее', 0): 35,
#   ('клиент', 0): 15,
#   ('хороший', 0): 135,
#   ('проектный', 0): 10,
#   ('получить', 0): 172,
#   ('грант', 0): 91,
#   ('вопрос', 0): 198,
#   ('разобрать', 0): 6,
#   ('сбор', 0): 15,
#   ('потребность', 0): 2,
#   ('общение', 0): 9,
#   ('представитель', 0): 44,
#   ('нко', 0): 2,
#   ('обзор', 0): 5,
#   ('разбор', 0): 1,
#   ('успешный', 0): 28,
#   ('история', 0): 32,
#   ('рф', 0): 40,
#   ('сборка', 0): 1,
#   ('сбалансированный', 0): 2,
#   ('компетенция', 0): 23,
#   ('придумать', 0): 3,
#   ('толковый', 0): 1,
#   ('блиц', 0): 1,
#   ('тренинг', 0): 10,
#   ('инструмент', 0): 14,
#   ('мозговой', 0): 2,
#   ('штурм', 0): 3,
#   ('поддержка', 0): 35,
#   ('фасилитатор', 0): 1,
#   ('презентация', 0): 48,
#   ('выбор', 0): 30,
#   ('перспективный', 0): 13,
#   ('дата', 0): 22,
#   ('аудитория', 0): 66,
#   ('регистрация', 0): 204,
#   ('раздел', 0): 21,
#   ('февраль', 0): 53,
#   ('неофициальный', 0): 1,
#   ('широко', 0): 3,
#   ('отмечать', 0): 3,
#   ('профессиональный', 0): 47,
#   ('компьютерщик', 0): 1,
#   ('заинтересованный', 0): 4,
#   ('первый', 0): 154,
#   ('реально', 0): 2,
#   ('электронный', 0): 16,
#   ('компьютер', 0): 17,
#   ('eniac', 0): 1,
#   ('numerical', 0): 1,
#   ('integrator', 0): 1,
#   ('and', 0): 22,
#   ('calculator', 0): 1,
#   ('сентябрь', 0): 60,
#   ('вновь', 0): 7,
#   ('пополнение', 0): 2,
#   ('первокурсник', 0): 83,
#   ('начать', 0): 26,
#   ('встреча', 0): 82,
#   ('программа', 0): 283,
#   ('бакалавриат', 0): 84,
#   ('образование', 0): 106,
#   ('мировой', 0): 15,
#   ('уровень', 0): 49,
#   ('востребовать', 0): 28,
#   ('специальность', 0): 24,
#   ('многие', 0): 20,
#   ('вперёд', 0): 5,
#   ('приём', 0): 94,
#   ('документ', 0): 113,
#   ('коллега', 0): 38,
#   ('просто', 0): 24,
#   ('подписчик', 0): 3,
#   ('защитник', 0): 2,
#   ('отечество', 0): 1,
#   ('последний', 0): 27,
#   ('повод', 0): 8,
#   ('поздравить', 0): 14,
#   ('мужчина', 0): 5,
#   ('проходить', 0): 92,
#   ('служба', 0): 4,
#   ('вооружённый', 0): 2,
#   ('сила', 0): 18,
#   ('гражданский', 0): 1,
#   ('профессия', 0): 39,
#   ('проявлять', 0): 2,
#   ('мужество', 0): 1,
#   ('героизм', 0): 1,
#   ('честь', 0): 6,
#   ('достоинство', 0): 2,
#   ('повседневный', 0): 3,
#   ('праздник', 0): 36,
#   ('кстати', 0): 24,
#   ('забывать', 0): 8,
#   ('пополнять', 0): 1,
#   ('календарь', 0): 3,
#   ('интересный', 0): 69,
#   ('ит', 0): 36,
#   ('родиться', 0): 1,
#   ('майкл', 0): 1,
#   ('делла', 0): 2,
#   ('основатель', 0): 16,
#   ('dell', 0): 2,
#   ('учёба', 0): 50,
#   ('основать', 0): 12,
#   ('продажа', 0): 9,
#   ('pc', 0): 2,
#   ('limited', 0): 3,
#   ('переименовать', 0): 1,
#   ('computer', 0): 6,
#   ('corporation', 0): 1,
#   ('состояние', 0): 6,
#   ('млрд', 0): 3,
#   ('строка', 0): 3,
#   ('список', 0): 36,
#   ('заключительный', 0): 16,
#   ('происходить', 0): 7,
#   ('получиться', 0): 9,
#   ('итог', 0): 29,
#   ('летний', 0): 24,
#   ('диляр', 0): 1,
#   ('габдреев', 0): 1,
#   ('образовательный', 0): 88,
#   ('сказать', 0): 18,
#   ('ректор', 0): 15,
#   ('дмитрий', 0): 22,
#   ('таюрский', 0): 4,
#   ('вручить', 0): 16,
#   ('денис', 0): 3,
#   ('алфёров', 0): 1,
#   ('тимур', 0): 10,
#   ('эмиль', 0): 3,
#   ('валиев', 0): 2,
#   ('разработка', 0): 150,
#   ('вестись', 0): 3,
#   ('течение', 0): 26,
#   ('данный', 0): 20,
#   ('момент', 0): 12,
#   ('посмотреть', 0): 28,
#   ('основный', 0): 25,
#   ('информация', 0): 110,
#   ('отчёт', 0): 2,
#   ('предыдущий', 0): 4,
#   ('донор', 0): 5,
#   ('скорый', 0): 9,
#   ('появиться', 0): 27,
#   ('возможность', 0): 125,
#   ('пожертвование', 0): 1,
#   ('подключить', 0): 2,
#   ('эквайринг', 0): 1,
#   ('безналичный', 0): 1,
#   ('платёж', 0): 7,
#   ('использование', 0): 27,
#   ('банковский', 0): 6,
#   ('карта', 0): 19,
#   ('бесконтактный', 0): 1,
#   ('оплата', 0): 16,
#   ('поддерживать', 0): 2,
#   ('дорабатывать', 0): 1,
#   ('функционал', 0): 4,
#   ('оценить', 0): 16,
#   ('реализация', 0): 27,
#   ('координация', 0): 2,
#   ('инициатива', 0): 11,
#   ('студент-активист', 0): 1,
#   ('казанский', 0): 92,
#   ('федеральный', 0): 79,
#   ('park', 0): 3,
#   ('webready', 0): 1,
#   ('добрый', 0): 25,
#   ('приглашать', 0): 150,
#   ('ваc', 0): 1,
#   ('принять', 0): 96,
#   ('web', 0): 13,
#   ('ready', 0): 5,
#   ('проводиться', 0): 39,
#   ('пятый', 0): 3,
#   ('министерство', 0): 34,
#   ('массовый', 0): 12,
#   ('коммуникация', 0): 15,
#   ('привлечь', 0): 5,
#   ('внимание', 0): 50,
#   ('инвестор', 0): 11,
#   ('обратный', 0): 4,
#   ('эксперт', 0): 52,
#   ('полуфиналист', 0): 1,
#   ('подготовка', 0): 53,
#   ('финал', 0): 19,
#   ('крупный', 0): 28,
#   ('нетворкинговый', 0): 1,
#   ('площадка', 0): 31,
#   ('ежегодно', 0): 12,
#   ('посещать', 0): 12,
#   ('it-бизнес', 0): 1,
#   ('стартап', 0): 26,
#   ('выйграть', 0): 1,
#   ('ценный', 0): 10,
#   ('приз', 0): 33,
#   ('подарок', 0): 22,
#   ('побороться', 0): 5,
#   ('призовой', 0): 26,
#   ('составлять', 0): 3,
#   ('миллион', 0): 10,
#   ('спонсор', 0): 3,
#   ('мероприятие', 0): 88,
#   ('состав', 0): 27,
#   ('жюри', 0): 16,
#   ('александр', 0): 21,
#   ('егоров', 0): 2,
#   ('дамиан', 0): 1,
#   ('доберштайна', 0): 1,
#   ('наталья', 0): 2,
#   ('касперский', 0): 1,
#   ('светлана', 0): 2,
#   ('никифоров', 0): 3,
#   ('игорь', 0): 4,
#   ('рябенький', 0): 1,
#   ('туркот', 0): 1,
#   ('павел', 0): 1,
#   ('черкашин', 0): 1,
#   ('чихачёв', 0): 1,
#   ('seed', 0): 1,
#   ('стадия', 0): 4,
#   ('запуск', 0): 2,
#   ('startup', 0): 17,
#   ('монетизироваться', 0): 1,
#   ('growth', 0): 1,
#   ('успех', 0): 30,
#   ('ещё', 0): 113,
#   ('дополнительный', 0): 37,
#   ('учредить', 0): 2,
#   ('корпорация', 0): 3,
#   ('емс', 0): 1,
#   ('кластер', 0): 5,
#   ('игровой', 0): 8,
#   ('финляндия', 0): 2,
#   ('playa', 0): 1,
#   ('приниматься', 0): 9,
#   ('source', 0): 6,
#   ('правило', 0): 23,
#   ('pravila', 0): 1,
#   ('we', 0): 7,
#   ('uspeha', 0): 1,
#   ('konkursa', 0): 1,
#   ('анонс', 0): 32,
#   ('тема', 0): 82,
#   ('стартовать', 0): 36,
#   ('бесплатный', 0): 42,
#   ('технический', 0): 39,
#   ('татьяна', 0): 5,
#   ('гвоздев', 0): 3,
#   ('phd', 0): 5,
#   ('окленд', 0): 4,
#   ('факультет', 0): 15,
#   ('теоретический', 0): 10,
#   ('информатика', 0): 40,
#   ('автор', 0): 18,
#   ('прикладной', 0): 14,
#   ('комбинаторика', 0): 2,
#   ('граф', 0): 3,
#   ('осветить', 0): 2,
#   ('несколько', 0): 29,
#   ('класс', 0): 45,
#   ('жизненный', 0): 1,
#   ('проблема', 0): 17,
#   ('метод', 0): 20,
#   ('алгоритм', 0): 19,
#   ('обход', 0): 1,
#   ('вершина', 0): 2,
#   ('теория', 0): 5,
#   ('кодирование', 0): 3,
#   ('причина', 0): 14,
#   ('эффективность', 0): 3,
#   ('способ', 0): 8,
#   ('взлом', 0): 1,
#   ('старинный', 0): 1,
#   ('код', 0): 22,
#   ('исправлять', 0): 2,
#   ('обнаруживать', 0): 1,
#   ('ошибка', 0): 4,
#   ('голосовать', 0): 5,
#   ('понравиться', 0): 4,
#   ('регистрироваться', 0): 18,
#   ('ауд', 0): 91,
#   ('выбрать', 0): 40,
#   ('утро', 0): 21,
#   ('видео', 0): 33,
#   ('залить', 0): 3,
#   ('видеозапись', 0): 8,
#   ('специально', 0): 13,
#   ('подготовить', 0): 27,
#   ('расписание', 0): 32,
#   ('медосмотр', 0): 3,
#   ('заселение', 0): 49,
#   ('общежитие', 0): 41,
#   ('перечень', 0): 14,
#   ('необходимый', 0): 39,
#   ('материал', 0): 22,
#   ('остаться', 0): 42,
#   ('задавать', 0): 27,
#   ('комментарий', 0): 17,
#   ('программный', 0): 45,
#   ('обеспечение', 0): 17,
#   ('начинать', 0): 23,
#   ('нуль', 0): 13,
#   ('настоящий', 0): 8,
#   ('достаточный', 0): 2,
#   ('ручной', 0): 4,
#   ('тестирование', 0): 34,
#   ('стоимость', 0): 25,
#   ('обучение', 0): 196,
#   ('продолжительность', 0): 8,
#   ('формат', 0): 36,
#   ('гибридный', 0): 6,
#   ('очный', 0): 34,
#   ('трансляция', 0): 44,
#   ('неделя', 0): 37,
#   ('практический', 0): 22,
#   ('адрес', 0): 70,
#   ('кремлёвский', 0): 109,
#   ('очно', 0): 12,
#   ('организовать', 0): 33,
#   ('онлайн', 0): 53,
#   ('сохранить', 0): 6,
#   ('измениться', 0): 5,
#   ('конференция', 0): 129,
#   ('java', 0): 121,
#   ('day', 0): 25,
#   ('kazan', 0): 52,
#   ('состояться', 0): 65,
#   ('давать', 0): 26,
#   ('доклад', 0): 39,
#   ('отбор', 0): 25,
#   ('завершиться', 0): 15,
#   ('заочный', 0): 9,
#   ('этап', 0): 77,
#   ('экспертиза', 0): 4,
#   ('университетский', 0): 7,
#   ('снять', 0): 1,
#   ('рассмотрение', 0): 3,
#   ('остальной', 0): 14,
#   ('пригласить', 0): 13,
#   ('онлайн-презентация', 0): 1,
#   ('тематический', 0): 2,
#   ('студенческий', 0): 53,
#   ('хирургический', 0): 1,
#   ('операционный', 0): 9,
#   ('программно-аппаратный', 0): 1,
#   ('комплекс', 0): 9,
#   ('vr', 0): 8,
#   ('перчатка', 0): 3,
#   ('каратэ', 0): 1,
#   ('digital', 0): 49,
#   ('twin', 0): 1,
#   ('арендовать', 0): 1,
#   ('помещение', 0): 7,
#   ('двойник', 0): 1,
#   ('происшествие', 0): 1,
#   ('уголовный', 0): 1,
#   ('делопроизводство', 0): 1,
#   ('создание', 0): 38,
#   ('экосистема', 0): 1,
#   ('принципиально', 0): 2,
#   ('иной', 0): 6,
#   ('степень', 0): 17,
#   ('улучшить', 0): 2,
#   ('упростить', 0): 4,
#   ('христианин', 0): 1,
#   ('перенос', 0): 2,
#   ('взаимодействие', 0): 8,
#   ('церковь', 0): 1,
#   ('священнослужитель', 0): 1,
#   ('плоскость', 0): 5,
#   ('посещение', 0): 5,
#   ('храм', 0): 3,
#   ('защита', 0): 19,
#   ('вуз', 0): 54,
#   ('приволжский', 0): 3,
#   ('округ', 0): 3,
#   ('удача', 0): 12,
#   ('применение', 0): 22,
#   ('дистанционный', 0): 28,
#   ('практико-ориентировать', 0): 1,
#   ('подход', 0): 15,
#   ('личность', 0): 4,
#   ('сходство', 0): 2,
#   ('профиль', 0): 62,
#   ('классический', 0): 8,
#   ('план', 0): 32,
#   ('совпадать', 0): 2,
#   ('содержание', 0): 4,
#   ('означать', 0): 2,
#   ('изучать', 0): 21,
#   ('дисциплина', 0): 17,
#   ('одинаковый', 0): 3,
#   ('название', 0): 20,
#   ('изучение', 0): 24,
#   ('наполнение', 0): 2,
#   ('семинарский', 0): 1,
#   ('экзамен', 0): 74,
#   ('диплом', 0): 45,
#   ('выпускник', 0): 65,
#   ('записать', 0): 7,
#   ('форма', 0): 50,
#   ('полностью', 0): 9,
#   ('включить', 0): 9,
#   ('процесс', 0): 39,
#   ('доступный', 0): 26,
#   ('уточнение', 0): 1,
#   ('режим', 0): 16,
#   ('реальный', 0): 35,
#   ('оба', 0): 3,
#   ('руб', 0): 39,
#   ('предоставляться', 0): 5,
#   ('разница', 0): 1,
#   ('лекционный', 0): 1,
#   ('блок', 0): 14,
#   ('реализовать', 0): 17,
#   ('дистанционно', 0): 12,
#   ('вариант', 0): 8,
#   ('фиксировать', 0): 1,
#   ('платформа', 0): 34,
#   ('microsoft', 0): 13,
#   ('teams', 0): 5,
#   ('вид', 0): 13,
#   ('ресурс', 0): 13,
#   ('онлайн-курс', 0): 2,
#   ('удобный', 0): 10,
#   ('обязательно', 0): 11,
#   ('сопровождаться', 0): 1,
#   ('it-специалист', 0): 4,
#   ('израиль', 0): 5,
#   ('барух', 0): 7,
#   ('садогурский', 0): 7,
#   ('младший', 0): 13,
#   ('брат', 0): 5,
#   ('вещество', 0): 3,
#   ('иностранный', 0): 43,
#   ('рука', 0): 12,
#   ('аттестат', 0): 8,
#   ('заверить', 0): 6,
#   ('паспорт', 0): 11,
#   ('мочь', 0): 149,
#   ('подавать', 0): 9,
#   ('заявление', 0): 58,
#   ('сдавать', 0): 15,
#   ('волна', 0): 17,
#   ('инструкция', 0): 8,
#   ('abiturient', 0): 9,
#   ('unity', 0): 20,
#   ('месяц', 0): 29,
#   ('долго', 0): 2,
#   ('настать', 0): 3,
#   ('хотеться', 0): 12,
#   ('отдельно', 0): 3,
#   ('новоиспечённый', 0): 8,
#   ('итисовец', 0): 5,
#   ('достойно', 0): 1,
#   ('сдать', 0): 15,
#   ('выпускной', 0): 11,
#   ('вступительный', 0): 41,
#   ('ит-команда', 0): 8,
#   ('добро', 0): 7,
#   ('пожаловать', 0): 5,
#   ('знакомиться', 0): 4,
#   ('переходить', 0): 15,
#   ('заполнять', 0): 1,
#   ('стикер', 0): 2,
#   ('telegram', 0): 10,
#   ('добавлять', 0): 3,
#   ('делиться', 0): 17,
#   ('пользоваться', 0): 7,
#   ('иметь', 0): 59,
#   ('комплектация', 0): 1,
#   ('оборудование', 0): 8,
#   ('робот', 0): 86,
#   ('инженер', 0): 11,
#   ('robotis-op', 0): 3,
#   ('kr', 0): 2,
#   ('agilus', 0): 1,
#   ('летательный', 0): 2,
#   ('аппарат', 0): 3,
#   ('рх', 0): 1,
#   ('квадракоптер', 0): 1,
#   ('dji', 0): 1,
#   ('арсенал', 0): 2,
#   ('lego', 0): 2,
#   ('mindstorms', 0): 1,
#   ('ev', 0): 1,
#   ('деталь', 0): 3,
#   ('expansion', 0): 1,
#   ('set', 0): 1,
#   ('датчик', 0): 6,
#   ('позволять', 0): 11,
#   ('провести', 0): 72,
#   ('очувствление', 0): 1,
#   ('моно', 0): 1,
#   ('камера', 0): 1,
#   ('лазерный', 0): 1,
#   ('дальномер', 0): 1,
#   ('российский', 0): 54,
#   ('беспилотный', 0): 13,
#   ('автомобиль', 0): 4,
#   ('скоро', 0): 27,
#   ('испанский', 0): 3,
#   ('мобильный', 0): 43,
#   ('pmb', 0): 1,
#   ('ит-предпринимательство', 0): 1,
#   ('продолжаться', 0): 16,
#   ('gamedev', 0): 8,
#   ('in', 0): 37,
#   ('cамай', 0): 2,
#   ('профессионал', 0): 10,
#   ('любитель', 0): 6,
#   ('апрель', 0): 61,
#   ('геймдизайн', 0): 2,
#   ('арт', 0): 4,
#   ('менеджмент', 0): 4,
#   ('знакомство', 0): 15,
#   ('ветеран', 0): 4,
#   ('индустрия', 0): 23,
#   ('число', 0): 47,
#   ('ограничить', 0): 6,
#   ('успеть', 0): 33,
#   ('зарегистрироваться', 0): 34,
#   ('подписываться', 0): 4,
#   ('телеграм', 0): 6,
#   ('канал', 0): 14,
#   ('aci', 0): 4,
#   ('student', 0): 9,
#   ('создать', 0): 45,
#   ('бот', 0): 18,
#   ('cтудента', 0): 2,
#   ('видеоигра', 0): 3,
#   ('прохладно', 0): 1,
#   ('поэтому', 0): 29,
#   ('согревать', 0): 1,
#   ('фотография', 0): 19,
#   ('топовый', 0): 4,
#   ('наиля', 0): 1,
#   ('шайхразиев', 0): 1,
#   ('android', 0): 13,
#   ('книга', 0): 9,
#   ('котлин', 0): 1,
#   ('action', 0): 1,
#   ('джемер', 0): 1,
#   ('исаков', 0): 1,
#   ('дж', 0): 3,
#   ('скин', 0): 1,
#   ('гринхол', 0): 1,
#   ('programmirovanie', 0): 1,
#   ('dlya', 0): 1,
#   ('professionalov', 0): 1,
#   ('дядюшка', 0): 1,
#   ('боб', 0): 1,
#   ('роберт', 0): 4,
#   ('мартин', 0): 4,
#   ('чистый', 0): 5,
#   ('архитектура', 0): 26,
#   ('искусство', 0): 8,
#   ('юдасити', 0): 1,
#   ('advanced', 0): 1,
#   ('with', 0): 8,
#   ('kotlin', 0): 7,
#   ('developing', 0): 1,
#   ('apps', 0): 2,
#   ('китайский', 0): 6,
#   ('грамота', 0): 7,
#   ('пригодиться', 0): 6,
#   ('тайна', 0): 3,
#   ('любопытный', 0): 1,
#   ('прямо', 0): 16,
#   ('региональный', 0): 10,
#   ('тур', 0): 15,
#   ('олимпиада', 0): 81,
#   ('март', 0): 59,
#   ('проходная', 0): 17,
#   ('балл', 0): 96,
#   ('грантовый', 0): 18,
#   ('задать', 0): 43,
#   ('вход', 0): 23,
#   ('свободный', 0): 27,
#   ('подтверждать', 0): 12,
#   ('требоваться', 0): 45,
#   ('хотеть', 0): 131,
#   ('егэ', 0): 57,
#   ('межрегиональный', 0): 3,
#   ('запись', 0): 22,
#   ('online', 0): 3,
#   ('youtube', 0): 9,
#   ('прямой', 0): 44,
#   ('эфир', 0): 51,
#   ('оставаться', 0): 6,
#   ('мск', 0): 12,
#   ('ответить', 0): 33,
#   ('хасьян', 0): 23,
#   ('айрат', 0): 39,
#   ('фаридович', 0): 13,
#   ('оставить', 0): 21,
#   ('пост', 0): 20,
#   ('instagram', 0): 30,
#   ('сотрудник', 0): 76,
#   ('главный', 0): 24,
#   ('iros', 0): 2,
#   ('ieee', 0): 4,
#   ('international', 0): 8,
#   ('conference', 0): 6,
#   ('on', 0): 11,
#   ('intelligent', 0): 1,
#   ('robotics', 0): 11,
#   ('цель', 0): 34,
#   ('обсуждение', 0): 16,
#   ('ознакомление', 0): 1,
#   ('автономный', 0): 8,
#   ('совместимый', 0): 2,
#   ('медицинский', 0): 21,
#   ('многое', 0): 19,
#   ('нейроморфный', 0): 11,
#   ('вычисление', 0): 21,
#   ('нейросимуляция', 0): 14,
#   ('робототехнический', 0): 37,
#   ('евгений', 0): 26,
#   ...},
#  {'ризван',
#   'напоить',
#   'западноевропейский',
#   'hardcore',
#   'полноправный',
#   'rogvald',
#   'versions',
#   'fomicheva',
#   'мацуно',
#   'vermintide',
#   'алимов',
#   'встречный',
#   'голощапов',
#   'учебно-производственный',
#   'принуждать',
#   'наставничество',
#   'lamp',
#   'хакатанов',
#   'путевой',
#   'цепочка',
#   'warno',
#   'удостоверить',
#   'миньон',
#   'ярус',
#   'колонизировать',
#   'strategic',
#   'инопланетный',
#   'зомби-апокалиптический',
#   'теслапанк',
#   'отыскать',
#   'аврора',
#   'цветковый',
#   'начальный',
#   'экономическо-градостроительный',
#   'структурировать',
#   'цена',
#   'портфолио',
#   'стойко',
#   'эпидемия',
#   'вокзал',
#   'совместно',
#   'зацикленный',
#   'географический',
#   'эбба',
#   'равилевич',
#   'растащить',
#   'кошарский',
#   'оптимизм',
#   'пустовать',
#   'satus',
#   'альф-тестирование',
#   'фасилитатор',
#   'дон',
#   'telegram-канал',
#   'жажда',
#   'молодеть',
#   'чегодаев',
#   'фимир',
#   'эквайринг',
#   'счесть',
#   'razrabotali',
#   'included',
#   'гайнатуллин',
#   'почасовой',
#   'откопать',
#   'базис',
#   'собирать',
#   'гравий',
#   'инди-новинка',
#   'заезд',
#   'мощность',
#   'after',
#   'стерпеть',
#   'диагностика',
#   'всегалактический',
#   'обвалиться',
#   'словосочетание',
#   'эп',
#   'в-третьих',
#   'определяться',
#   'утопать',
#   'становиться',
#   'пометка',
#   'раскрытие',
#   'варяжский',
#   'огненный',
#   'doctor',
#   'беззаконие',
#   'недра',
#   'гласить',
#   'дворфик',
#   'supreme',
#   'конгресс',
#   'харага',
#   'залегать',
#   'admiral',
#   'озвучить',
#   'megacon',
#   'mail',
#   'поправка',
#   'француз',
#   'npc',
#   'redemption',
#   'bit',
#   'мгновенно',
#   'квантовый',
#   'шпильман',
#   'рафаэль',
#   'кусать',
#   'прямиком',
#   'летний',
#   'отнестись',
#   'дварф',
#   'варфара',
#   'неоднозначный',
#   'послать',
#   'искра',
#   'измениться',
#   'пасмурный',
#   'фпс',
#   'приветствоваться',
#   'алмаз',
#   'коллега',
#   'hr',
#   'growth',
#   'минимальный',
#   'несоизмеримый',
#   'робот-инженер',
#   'аниматор',
#   'админовый',
#   'окрестность',
#   'лёгкое',
#   'ит-факультет',
#   'бизнес-модель',
#   'folding',
#   'посетитель',
#   'регламентировать',
#   'предположительно',
#   'бороздить',
#   'indiegogo',
#   'нереалистичный',
#   'копейка',
#   'высокореалистичный',
#   'дозволяться',
#   'спринт',
#   'загрузочный',
#   'наигранный',
#   'администрирование',
#   'правосудие',
#   'активация',
#   'universe',
#   'дипломатически',
#   'strategium-dnevnik',
#   'длинный',
#   'anchor',
#   'блохин',
#   'красочный',
#   'don',
#   'олеск',
#   'мутон',
#   'киргизия',
#   'починить',
#   'бушевать',
#   'каменоломня',
#   'removes',
#   'старинный',
#   'семнадцатый',
#   'снайпер',
#   'comics',
#   'кузница',
#   'лайкнуть',
#   'назначить',
#   'kickstarter',
#   'приезд',
#   'дивиденд',
#   'сказка',
#   'тема',
#   'термоядерный',
#   'подъёмник',
#   'окупаться',
#   'безпалов',
#   'затормаживать',
#   'сборка',
#   'аттестат',
#   'ghz',
#   'речевой',
#   'раковина',
#   'вибрация',
#   'gsc',
#   'итисовец',
#   'слэмера',
#   'молчание',
#   'ольга',
#   'танковать',
#   'наггарот',
#   'евгений',
#   'усилие',
#   'перенастройка',
#   'кпп',
#   'utv',
#   'mask',
#   'magic',
#   'отполировать',
#   'triple',
#   'косталтын',
#   'скаут',
#   'прилагаться',
#   'перерезать',
#   'чреватый',
#   'обследование',
#   'подкидывать',
#   'student',
#   'виват',
#   'лирс',
#   'публично',
#   'беременность',
#   'платный',
#   'победительница',
#   'закуска',
#   'возмужать',
#   'догма',
#   'ранее',
#   'zombie',
#   'честной',
#   'всепоглощающий',
#   'konkursa',
#   'провинция',
#   'факультатив',
#   'vr-тренажёр',
#   'буря',
#   'навигатор',
#   'приспосабливаться',
#   'камера',
#   'нескоро',
#   'выполнить',
#   'ка',
#   'образно',
#   'подумать',
#   'open',
#   'кариб',
#   'дать',
#   'зрительский',
#   'юнир',
#   'исландка',
#   'телеоператор',
#   'развиваться',
#   'лозунг',
#   'каждый',
#   'запросить',
#   'пообещать',
#   'вглядываться',
#   'смола',
#   'веб-браузер',
#   'наказать',
#   'пускай',
#   'информационный',
#   'предсказать',
#   'обнаружение',
#   'platoon',
#   'заскучать',
#   'отобразиться',
#   'также',
#   'готический',
#   'сбивать',
#   'присыпать',
#   'удвоение',
#   'стабилизировать',
#   'belov',
#   'анисимов',
#   'оплавление',
#   'дар',
#   'обри',
#   'экспериментальный',
#   'дарить',
#   'прихватить',
#   'перестройка',
#   'иво',
#   'ремонтировать',
#   'туррель',
#   'концепт',
#   'quad',
#   'викторина',
#   'поликлиника',
#   'алик',
#   'бородин',
#   'петраковский',
#   'труба',
#   'механик',
#   'гомера',
#   'приближение',
#   'ретроспектива',
#   'интернет-граф',
#   'эстетика',
#   'горстка',
#   'ку',
#   'neuralink',
#   'хозяин',
#   'демократический',
#   'zeptolab',
#   'сильвер',
#   'одобрение',
#   'cerevrum',
#   'казна',
#   'соседний',
#   'великодушный',
#   'требование',
#   'ливерпуль',
#   'администрация',
#   'креативность',
#   'преподаватель',
#   'youtube-канал',
#   'манер',
#   'хосе',
#   'короткий',
#   'unics',
#   'объединить',
#   'глашатай',
#   'случайный',
#   'выживалка',
#   'skylines',
#   'инди-разработчик',
#   'кристально',
#   'gamereactor',
#   'открыться',
#   'чувствовать',
#   'радиация',
#   'опасаться',
#   'сжигание',
#   'орба',
#   'канализационный',
#   'hegyi',
#   'поимка',
#   'элина',
#   'кровать',
#   'стипендиальный',
#   'соревновательный',
#   'jornada',
#   'загородка',
#   'udacity',
#   'крепость',
#   'распространиться',
#   'ti',
#   'трофим',
#   'openlab',
#   'аттил',
#   'чистополь',
#   'frozen',
#   'озеленение',
#   'брон',
#   'совмещать',
#   'подстраховывать',
#   'работник',
#   'minsky',
#   'кальдерий',
#   'перерисовать',
#   'it-сокровище',
#   'лампа',
#   'охват',
#   'прозвучать',
#   'длительный',
#   'маркетинговый',
#   'бессмертный',
#   'друг-феодал',
#   'смертоносный',
#   'чай',
#   'эо',
#   'художественный',
#   'известно',
#   'students',
#   'вторник',
#   'миссисипский',
#   'сладость',
#   'потребовать',
#   'funatics',
#   'стратёжка',
#   'лем',
#   'концепция',
#   'effects',
#   'среднеазиатский',
#   'импакт',
#   'следить',
#   'whatsapp',
#   'языческий',
#   'численно',
#   'даниса',
#   'вызывающе',
#   'текан',
#   'паки',
#   'посол',
#   'лечить',
#   'ironharvest',
#   'deck',
#   'родственник',
#   'претендовать',
#   'конфедерация',
#   'отдалить',
#   'чомбить',
#   'мини-обзор',
#   'возродиться',
#   'неопытный',
#   'транспортно-пересадочный',
#   'focus',
#   'военный',
#   'resort',
#   'дейвид',
#   'нетология',
#   'развозить',
#   'бизнес-задача',
#   'икарус',
#   'эмуляция',
#   'публиковаться',
#   'газовый',
#   'хюрри',
#   'остерегаться',
#   'бордеть',
#   'пополняться',
#   'тартар',
#   'заложить',
#   'погубить',
#   'вокруг',
#   'операция',
#   'феодализм',
#   'бесчисленный',
#   'строиться',
#   'оптимальный',
#   'привести',
#   'чженя',
#   'соблазнение',
#   'чей',
#   'signals',
#   'продать',
#   'разведчик',
#   'русский',
#   'флотилия',
#   'бтр-д',
#   'подвижка',
#   'уличить',
#   'пластмасса',
#   'связь',
#   'гринд',
#   'поохотиться',
#   'приквел',
#   'красиво',
#   'лайк',
#   'z-collapse',
#   'щуплый',
#   'хадий',
#   'неоднократно',
#   'sengoku',
#   'контакт',
#   'археолог',
#   'command',
#   'гарнизон',
#   'иванкевич',
#   'агония',
#   'апгрейд',
#   'трубопровод',
#   'неполный',
#   'мышка',
#   'абатур',
#   'отдача',
#   'определять',
#   'community',
#   'вправо',
#   'полстен',
#   'осенний',
#   'буддизм',
#   'свинцовый',
#   'отрабатывать',
#   'соц',
#   'прозябать',
#   'роль',
#   'отделять',
#   'вcё',
#   'садовник',
#   'высвободить',
#   'оргкомитет',
#   'протаптываться',
#   'записываться',
#   'юлия',
#   'патронат',
#   'taxil',
#   'kazani',
#   'информирование',
#   'срубить',
#   'авиация',
#   'бизнес-премия',
#   'роща',
#   'переделать',
#   'наткнуться',
#   'инициатива',
#   'defense',
#   'desperados',
#   'экстремальный',
#   'поностальгировать',
#   'пулемётный',
#   'противогаз',
#   'айрат',
#   'рандомайзер',
#   'немец',
#   'горканавт',
#   'рябенький',
#   'маркграфство',
#   'неправильный',
#   'haven',
#   'ит-команда',
#   'отгреметь',
#   'сбросовый',
#   'социал-либеральный',
#   'накрутка',
#   'красться',
#   'положить',
#   'семинар',
#   'сумасшествие',
#   'сохранение',
#   'венера',
#   'фотограф',
#   'переполнять',
#   'вуз',
#   'насколько',
#   'мчаться',
#   'беженец',
#   'полуфинал',
#   'сервисный',
#   'реформировать',
#   'зуденбург',
#   'комиссия',
#   'уйти',
#   'описывать',
#   'collaborative',
#   'прослойка',
#   'battletech',
#   'shining',
#   'консилиум',
#   'штрафовать',
#   'истинный',
#   'twitter-страница',
#   'сказитель',
#   'деревенька',
#   'внутри',
#   'принтер',
#   'опустеть',
#   'статус-кво',
#   'титульный',
#   'отец',
#   'скотобойня',
#   'improvement',
#   'flow',
#   'клименко',
#   'неуловимый',
#   'бразилия',
#   'регресс',
#   'поздний',
#   'приложение',
#   'неодарённый',
#   'нарекание',
#   'превью-билд',
#   'сникча',
#   'русло',
#   'tacam',
#   'урезанный',
#   'радиоактивный',
#   'билярый',
#   'собранный',
#   'блиц-интервью',
#   'куплять',
#   'терпеть',
#   'googleplay',
#   'поговаривать',
#   'далеко',
#   'plague',
#   'плоть',
#   'access',
#   'premium',
#   'спальня',
#   'щедрость',
#   'раб',
#   'главный',
#   'am',
#   'раскидываться',
#   'created',
#   'darewise',
#   'покупать',
#   'морось',
#   'отображаться',
#   'поселенец',
#   'монастырь',
#   'избавление',
#   'средиземноморский',
#   'самосвал',
#   'клеточный',
#   'перенаселение',
#   'ия-конкурент',
#   'batman',
#   'цитировать',
#   'несерьёзно',
#   'батарея',
#   'вроп',
#   'дино',
#   'days',
#   'разбан',
#   'кишка',
#   'приветственный',
#   'анестетик',
#   'подверженный',
#   'посыл',
#   'обводка',
#   'заручиться',
#   'книт',
#   'море',
#   'старый',
#   'англоязычный',
#   'rimworld',
#   'леона',
#   'озеро',
#   'шотландский',
#   'фарич',
#   'route',
#   'ветвь',
#   'квадратный',
#   'contest',
#   'ранний',
#   'щадить',
#   'увеличение',
#   'бурение',
#   'наряд',
#   'многообещающий',
#   'киберпанк-сити',
#   'wg',
#   'псайкер-человек',
#   'ультуан',
#   'внимание',
#   'подвиг',
#   'вымучить',
#   'герой',
#   'одноимённый',
#   'геймпада',
#   'ускользнуть',
#   'зарекомендовать',
#   'никуда',
#   'фермерство',
#   'норланда',
#   'будни',
#   'загулов',
#   'транспорт',
#   'невозможность',
#   'полевой',
#   'неохлаждаемый',
#   'kainga',
#   'прибыльно',
#   'очистить',
#   'альбедо',
#   'cyberpunk',
#   'army',
#   'присуждение',
#   'espiocracy',
#   'урбанистика',
#   'тимур',
#   'видяха',
#   'нанять',
#   'ассигнование',
#   'ривия',
#   'оберегать',
#   'настраиваться',
#   'офлайн-митап',
#   'сомневаться',
#   'вызнать',
#   'ильдарович',
#   'sacrifice',
#   'пост-апокалипсис',
#   'терпеться',
#   'морковка',
#   'ноц',
#   'игрофикация',
#   'cthulhu',
#   'нато',
#   'ecommerce',
#   'подвижный',
#   'отвернуться',
#   'министр',
#   'phone',
#   'киевский',
#   'гбу',
#   'фановый',
#   'азалия',
#   'уругвай',
#   'гостёха',
#   'зависнуть',
#   'утомить',
#   'online',
#   'мышь-переросток',
#   'благо',
#   'дилофозавр',
#   'поверьте',
#   'standoff',
#   'репа',
#   'вааагха',
#   'волга',
#   'окоп',
#   'глиняный',
#   'империя-экспансионист',
#   'сюда',
#   'выбраться',
#   'настройка',
#   'детально',
#   'strategium',
#   'schaffhausen',
#   'фортификация',
#   'придумывать',
#   'ассортимент',
#   'возводиться',
#   'капризный',
#   'наковальня',
#   'угнетение',
#   'ветеран-тевтонец',
#   'chat',
#   'поражение',
#   'катушка',
#   'силуэт',
#   'попортить',
#   'ost',
#   'оперативный',
#   'обвязка',
#   'небожитель-ксенофил',
#   'раздавать',
#   'бросаться',
#   'keyga',
#   'массивный',
#   'око',
#   'второстепенный',
#   'нарастать',
#   'engineering',
#   'ночью',
#   'неведомый',
#   'краска',
#   'вложение',
#   'хлеб',
#   'залить',
#   'морозостойкость',
#   'зрелище',
#   'доцент',
#   'глубокий',
#   'кооперация',
#   'моисеев',
#   'sec',
#   'сочинение',
#   'заставка',
#   'любовный',
#   'размещение',
#   'ильсия',
#   'венеция',
#   'конструкторский',
#   'планироваться',
#   'stellaris',
#   'кое-какой',
#   'февраль',
#   'gta',
#   'гномий',
#   'зарина',
#   'увлекательный',
#   'капитализм',
#   'воспеть',
#   'сканирование',
#   'государственный',
#   'вонзаться',
#   'эквадор',
#   'пушистый',
#   'данилов',
#   'there',
#   'механика',
#   'дебил',
#   'текст',
#   'мелкий',
#   'mobile-разработка',
#   'святейшество',
#   'информбюро',
#   'танцевальный',
#   'armada',
#   'санкт-петербург',
#   'командир',
#   'чертовски',
#   'безусловно',
#   'дух',
#   'осуществить',
#   'предпоследний',
#   'движение',
#   'эвакуировать',
#   'георгий',
#   'деревянный',
#   'гу',
#   'техасский',
#   'подсветка',
#   'совладелец',
#   'dagger',
#   'станция-ковчег',
#   'наполнить',
#   'анубиса',
#   'urban',
#   'predictor',
#   'трава',
#   'esma',
#   'леорик',
#   'сажи',
#   'щит',
#   'осмеливаться',
#   'тариф',
#   'безупречно',
#   'автоматон',
#   'либо',
#   'навязывание',
#   'смирнов',
#   'кипения-казань',
#   'ит-фестиваль',
#   'деканат',
#   'albion',
#   'сенсорный',
#   'хэм',
#   'спастись',
#   'эид',
#   'потенциальный',
#   'станционный',
#   'гегемония',
#   'умелый',
#   'культорг',
#   'заполучить',
#   'яростно',
#   'академический',
#   'интернет-магазин',
#   'контактный',
#   'нейрональный',
#   'бензин',
#   'обновиться',
#   'видеоматериал',
#   'ryan',
#   'hr-команда',
#   'шутка',
#   'вчера',
#   'memnon',
#   'репродукция',
#   'overland',
#   'тусклый',
#   'астероид',
#   'сверхпроводник',
#   'личный',
#   'утроить',
#   'covid',
#   'военно-морской',
#   'аспирантка',
#   'контора',
#   'бордюр',
#   'число',
#   'навстречу',
#   'итальянский',
#   'однажды',
#   'набивание',
#   'подогреть',
#   'терракотовый',
#   'неон',
#   'защищаться',
#   'обдувать',
#   'привносить',
#   'шаймуратов',
#   'заключение',
#   'синапс',
#   'рх',
#   'старт',
#   'парад',
#   'армения',
#   'вор',
#   'konkursvk',
#   'предстоящий',
#   'снегопад',
#   'ставка',
#   'действо',
#   'удалённый',
#   'венгерский',
#   'шт',
#   'метростроевец',
#   'прошлый',
#   'видео-отчёт',
#   'coals',
#   'равнинный',
#   'vram',
#   'исчерпывающий',
#   'гипотетически',
#   'сородич',
#   'утро',
#   'диагноз',
#   'итисовский',
#   'лифт',
#   'scrumtrek',
#   'сдвигаться',
#   'morrowind',
#   'график',
#   'агапов',
#   'конюшня',
#   'сардаукар',
#   'вытеснить',
#   'потесниться',
#   'идентифицировать',
#   'twitter',
#   'убирать',
#   'осуществление',
#   'отринуть',
#   'мартин',
#   'жаркий',
#   'habitat',
#   'прикольный',
#   'сдерживать',
#   'бронежилет',
#   'библиотека',
#   'справедливый',
#   'zoo',
#   'коврик',
#   'универ',
#   'стабильный',
#   'переосмысление',
#   'itistuqay',
#   'султанат',
#   'серверный',
#   'мифический',
#   'mmorts',
#   'кардинал',
#   'дифицит',
#   'конституционный',
#   'дверь',
#   'туристический',
#   'погодный',
#   'тепловой',
#   'cadet',
#   'возврат',
#   'кастилия',
#   'сортировка',
#   'книжный',
#   'death',
#   'оао',
#   'отбытие',
#   'поезд',
#   'положительно',
#   'пропустить',
#   'вербер',
#   'речной',
#   'наёмница',
#   'айгуль',
#   'mozgami',
#   'противопоказание',
#   'spoils',
#   'rodeo',
#   'баллиста',
#   'груз',
#   'потерянный',
#   'fow',
#   'отладочный',
#   'участие',
#   'удостоиться',
#   'применяться',
#   'рука',
#   'инвестиционно-венчурный',
#   'черёд',
#   'скавено',
#   'темп',
#   'хирургический',
#   'жарко',
#   'stronghold',
#   'переговоры',
#   'бородатый',
#   'зависимость',
#   'оперативно',
#   'mythology',
#   'размножение',
#   'уникальный',
#   'композитный',
#   'морёв',
#   'исламский',
#   'выбить',
#   'ввести',
#   'водрузить',
#   'агамемнон',
#   'платформа',
#   'реально',
#   'житель',
#   'меню',
#   'стекло',
#   'постоянно',
#   'цифра',
#   'грянуть',
#   'потенциально',
#   'массачусетский',
#   'заключать',
#   'спутник',
#   'восприниматься',
#   'космофлот',
#   'предъявление',
#   'трудный',
#   'любящий',
#   'пересечение',
#   'приток',
#   'видеоускоритель',
#   'набережная',
#   'случай',
#   ...})
